# %% [markdown]
# # Auditoría Híbrida Principal
# **Refactorización Modular para GitHub**
#
# Este notebook ejecuta el pipeline completo de autenticación de papel moneda, importando las funcionalidades desde la carpeta modulos/ para mantener el código limpio y legible.

# %%
import sys
import os

# Ajustar ruta para importar módulos desde el directorio padre
sys.path.append(os.path.abspath('../'))

from modulos.ai_router import HybridRouter
from modulos.visualizer import audit_hybrid_tolerant

# Inicializar la Red Neuronal (IA)
router_cnn = HybridRouter(model_path='../models/best_model_EfficientNet.pth')

# %%
# Auditar Billete Sospechoso
imagen_sospechosa = '../data/test_images/20ARESCA.jpg'
audit_hybrid_tolerant(imagen_sospechosa, router_cnn, profiles_path='../perfiles_pds/')
